# %%
# 한줄 주석이에요(R의 주석과 똑같다 !)
# 여러줄의 주석은 """  요거나  """  , ''' 요거 '''

"""

python의 장점
- 상대적으로 쉬운 언어
- 강력한 데이터 분석 library(현재 가장 인기가 좋다!)
- Open Source
- R에 비해서 범용적인 사용이 가능
- 데이터 분석 결과를 다른 시스템과 연동시킬 때 좋다!
- 하위 호환성이 없다(버전 2.x와 3.x는 다르다 )
- PyCharm 혹은 jupyter notebook으로 작업하자(jupyter notebook가 더 좋음)

"""

"""
[셀을 파란색으로 만들고]
B : 새로운 셀을 아래쪽에 만들 때
A : 새로운 셀을 위쪽에 만들 때
DD : 기존 셀을 지우고 싶을 때
O : OUTPUT영역을 보이고, 안보이게
L : 라인번호에 대한 toggle

"""


# python의 keyword
# keyword 모듈을 로딩하자
import keyword

# output영역에 출력할 때 사용하는 함수 : print()
print(keyword.kwlist)

# 셀을 실행하면 입력한 것들이 실행됨
"""
[jupyter notebook hotkey(단축키)]
ctrl + ENTER : 현재 셀 실행
alt + ENTER : 현재 셀 실행, 아래쪽에 cell 삽입
shift + ENTER : 현재 셀 실행, 아래쪽 cell 선택(아래쪽에 cell이 있을 때, 없을 때는 새로 한개 만들고 선택)

"""

# R은 FALSE(대문자), python은 False (앞글자만 대문자) 등의 차이점 확인하기! 


## 변수를 생성하고 삭제해보자
# <- 못쓴다. = 사용하기
var1 = 100;
var2 = 200
# 세미콜론은 생략이 가능하다
var1,var2
print(var1,var2)
print(var1)
print(var2)
print((var1,var2))
# output에 출력할 때 print()를 이용
print("var2의 값은 : ", var2, "입니다")
del var2
#del은 변수 지우기
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 100 200
# 100
# 200
# (100, 200)
# var2의 값은 :  200 입니다

# %%
# python
#1. 환경설정
# 1) pyCharm IDE를 이용해서 개발할 수 있다.
#   여러명이 같은 파일, 프로젝트를 공유하면서 개발할 때 유리하다
#   interactive한 개발이 힘들다.
#   데이터분석작업보다는 web개발이나 다른 application작성
# 2) Jupyter Notebook
#    Interactive한 개발이 가능해서 데이터분석에 대한 학습, 실제 분석작업을 많이 한다
#    여러명이 공동작업할 때는 불편할 수 있다.

#2. jupyter notebook 사용방법
# 1) 셀 생성, 셀 안의 코드 실행방법
#    셀 삭제
#    무한 루프가 되면 실행 interrupt (*)

#3. python built-in types
#   - Numeric(integer, float, complex)
#   - Text sequence(str)
#   - Sequence(=자료구조, list, tuple, range)
#   - Mapping Type(Json)
#   - Bool Type(bool)
#   - Set Type(set)
